# %%
import csv
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import json
import ast

# %%
driver=webdriver.Chrome(executable_path='D:\chromedriver.exe')
driver.maximize_window()

# %%
def model_key_lower_and_sort(k):
    k["key"]=k["key"].lower().replace(' ','').replace('-','')
    k["name"]=(k["name"].upper())
    return len(k["key"]),k["name"]

# %%
with open('../../models/headset_model.json') as json_file:
    model = json.load(json_file)

# %%
model.sort(key=model_key_lower_and_sort ,reverse=True)

# %%
model_key=[]
model_name=[]

# %%
for i in model:
    model_key.append(i["key"])
    model_name.append(i["name"])

# %%
def moused_exit(url):
    
    with open("../../models/headsetSchema.json") as json_file:
        mouse_schema = json.load(json_file)

    spec_type_arr = []
    spec_details_arr = []
    spec = {}

    #     get url and scroll 5 sec
    driver.get(url)

    #     find name and compare
    try:
        find_name = driver.find_elements_by_xpath(
            '//*[@id="__layout"]/div/main/section/div[1]/div[2]/div[1]/h1'
        )  # change
        name = find_name[0].text

        name_lower = (
            name.lower()
            .replace(" ", "")
            .replace("-", "")
            .replace("gaming", "")
            # .replace("tenkeyless", "tkl")
        )
        print(name)
        compare = [x for x in model_key if x in name_lower]
        print(compare[0])
        mouse_schema["model"] = compare[0]

        if compare:
            for index, val in enumerate(model_key):
                if compare[0] == model[index]["key"]:
                    mouse_schema["name"] = model[index]["name"]

        find_price = driver.find_elements_by_xpath(
            '//*[@id="__layout"]/div/main/section/div[1]/div[2]/div[1]/div[3]/div/div[1]'
        )  # change
        price = find_price[0].text.replace(",", "").replace("฿", "")
        print(price)

        find_image = driver.find_elements_by_xpath(
            '//*[@id="__layout"]/div/main/section/div[1]/div[1]/div/div[1]/div[1]/div[5]/div/img'
        )  # change
        image = find_image[0].get_attribute("src")
        print(image)

        find_brand = driver.find_elements_by_xpath(
            '//*[@id="__layout"]/div/main/section/div[1]/div[2]/div[1]/div[1]/div/div[1]/span[2]'
        )  # change
        brand = find_brand[0].text
        print(brand)

        mouse_schema["data"][0]["name"] = name.upper()
        mouse_schema["data"][0]["price"] = int(price)
        mouse_schema["data"][0]["href"] = url
        mouse_schema["data"][0]["image"] = image
    

        mouse_schema["store"] = "banana".capitalize()  # change
        mouse_schema["brand"] = brand.capitalize()  # change
        mouse_schema["category"] = "headset".capitalize()  # change
        mouse_schema["tag"] = "gaming".capitalize()  # change
        print(mouse_schema["data"][0]["href"])
        find_spec_type = driver.find_elements_by_xpath(
            '//*[@id="__layout"]/div/main/section/section[1]/div/div/table/tbody/tr/td[1]'
        )  # change
        find_spec_details = driver.find_elements_by_xpath(
            '//*[@id="__layout"]/div/main/section/section[1]/div/div/table/tbody/tr/td[2]'
        )  # change

        for i in find_spec_type:
            spec_type_arr.append(i.text)
        for i in find_spec_details:
            spec_details_arr.append(i.text)
        for index, val in enumerate(spec_type_arr):
            spec[val] = spec_details_arr[index]
        for index, val in enumerate(spec_type_arr):
            if val == "Connector":  # change
                mouse_schema["data"][0]["spec"]["interface"] = spec_details_arr[
                    index
                ]
            if val == "Type_of":  # change
                mouse_schema["data"][0]["spec"]["type_of"] = spec_details_arr[index]
            if val == "Headphone Frequency Response":  # change
                mouse_schema["data"][0]["spec"]["frequency"] = spec_details_arr[
                    index
                ]
            if val == "Headphone Input Impedance":  # change
                mouse_schema["data"][0]["spec"]["impedance"] = spec_details_arr[index]
            if val == "Microphone":  # change
                mouse_schema["data"][0]["spec"]["microphone"] = spec_details_arr[index]
            # if(val=="Brand"): #change
            #     keyboard_schema["brand"]=spec_details_arr[index].capitalize()
        return mouse_schema
    except:
        pass

# %%
# def name_exist(name):
#     try:
#         name_lower=name.lower().replace(' ','').replace('-','').replace('gaming','').replace('tenkeyless','tkl')
#         compare = [x for x in model_key if x in name_lower]
#         print(compare[0] ,">",name)
#     except:
#         pass
#     if(compare):
#         pass
#     else:
#         print(">",name)

# %%
testhref = "https://www.bnn.in.th/th/p/home-entertainment/headphone/headphone-full-size-headset/anitech-headphone-with-mic-ak39-black-3410411215196_zogwxr"

# %%
moused_exit(testhref)
# Out:
# Anitech Headphone with Mic. AK39 Black
# ak39
# 275
# https://media-cdn.bnn.in.th/14571/3410411215196-1-square_medium.jpg
# ANITECH
# https://www.bnn.in.th/th/p/home-entertainment/headphone/headphone-full-size-headset/anitech-headphone-with-mic-ak39-black-3410411215196_zogwxr
# {'model': 'ak39',
#  'name': 'ANITECH HEADPHONE WITH MIC. AK39',
#  'store': 'Banana',
#  'brand': 'Anitech',
#  'category': 'Headset',
#  'tag': 'Gaming',
#  'data': [{'name': 'ANITECH HEADPHONE WITH MIC. AK39 BLACK',
#    'price': 275,
#    'href': 'https://www.bnn.in.th/th/p/home-entertainment/headphone/headphone-full-size-headset/anitech-headphone-with-mic-ak39-black-3410411215196_zogwxr',
#    'image': 'https://media-cdn.bnn.in.th/14571/3410411215196-1-square_medium.jpg',
#    'spec': {'interface': '',
#     'type_of': '',
#     'frequency': '',
#     'impedance': '',
#     'microphone': ''}}]}

# %%
with open('banana_headset_gaming_href.txt', 'r') as f:
    banana_headset_gaming_href = ast.literal_eval(f.read())

# %%
with open('banana_headset_working_href.txt', 'r') as f:
    banana_headset_working_href = ast.literal_eval(f.read())

# %%
# advice_keyboard_gaming_href

# %%
print(banana_headset_working_href)
# Out:
# ['https://www.bnn.in.th/th/p/home-entertainment/headphone/in-ear-headphone/1-more-in-ear-wireless-tws-comfo-buds-pro-black-6933037201178_r02mmy', 'https://www.bnn.in.th/th/p/home-entertainment/headphone/in-ear-headphone/1-more-in-ear-wireless-tws-comfo-buds-pro-white-6933037201185_zp5llo', 'https://www.bnn.in.th/th/p/home-entertainment/headphone/headphone-earbuds/1-more-in-ear-wireless-tws-comfobuds-black-6933037200416_dn9kk6', 'https://www.bnn.in.th/th/p/home-entertainment/headphone/headphone-earbuds/1-more-in-ear-wireless-tws-comfobuds-white-6933037200409_z78jj0', 'https://www.bnn.in.th/th/p/home-entertainment/headphone/in-ear-headphone/1-more-in-ear-wireless-tws-colour-buds-black-6933037227123_d22kkx', 'https://www.bnn.in.th/th/p/home-entertainment/headphone/headphone-full-size-headset/aftershokz-aeropex-blue-eclipse-811071032155_
# https://media-cdn.bnn.in.th/41606/5707119029568-3-square_medium.jpg
# STEELSERIES
# https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-headphone/steelseries-gaming-headset-arctis-pro-gamedac-5707119029568_ze461d
# ---- 88 of 92 ----
# SteelSeries Gaming Headset Arctis Pro + GameDac White
# arctispro
# 8990
# https://media-cdn.bnn.in.th/41807/SteelSeries-Gaming-Headset-Arctis-Pro-and-GameDac-White-3-square_medium.jpg
# STEELSERIES
# https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-headphone/steelseries-gaming-headset-arctis-pro-gamedac-white-5707119036245_dne0gd
# ---- 89 of 92 ----
# SteelSeries Gaming Headset Arctis Pro Wireless
# arctisprowireless
# 12990
# https://media-cdn.bnn.in.th/41607/5707119029605-01-square_medium.jpg
# STEELSERIES
# https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-headphone/steelseries-gaming-headset-arctis-pro-wireless-5707119029605_z3mg1r
# ---- 90 of 92 ----
# SteelSeries Gaming Headset Arctis Pro Wireless White
# arctisprowireless
# 12990
# https://media-cdn.bnn.in.th/41813/SteelSeries-Gaming-Headset-Arctis-Pro-Wireless-White-3-square_medium.jpg
# STEELSERIES
# https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-headphone/steelseries-gaming-headset-arctis-pro-wireless-white-5707119036269_r0xqnr
# ---- 91 of 92 ----
# SteelSeries Gaming Headset TUSQ In-Ear Black
# tusq
# 1490
# https://media-cdn.bnn.in.th/42019/SteelSeries-Gaming-Headset-TUSQ-In-Ear-Black-5-square_medium.jpg
# STEELSERIES
# https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-headphone/steelseries-gaming-headset-tusq-in-ear-black-5707119043755_d289pd

# %%
out_headset_item= json.dumps(export, ensure_ascii=False)

# %%
out_headset_item
# Out:
# '[{"model": "ak39", "name": "ANITECH HEADPHONE WITH MIC. AK39", "store": "Banana", "brand": "Anitech", "category": "Headset", "tag": "Gaming", "data": [{"name": "ANITECH HEADPHONE WITH MIC. AK39 BLACK", "price": 275, "href": "https://www.bnn.in.th/th/p/home-entertainment/headphone/headphone-full-size-headset/anitech-headphone-with-mic-ak39-black-3410411215196_zogwxr", "image": "https://media-cdn.bnn.in.th/14571/3410411215196-1-square_medium.jpg", "spec": {"interface": "", "type_of": "", "frequency": "", "impedance": "", "microphone": ""}}]}, {"model": "ak71", "name": "ANITECH HEADPHONE WITH MIC. AK71", "store": "Banana", "brand": "Anitech", "category": "Headset", "tag": "Gaming", "data": [{"name": "ANITECH HEADPHONE WITH MIC. AK71 BLACK", "price": 299, "href": "https://www.bnn.in.th/th/p/home-entertainment/headphone/headphone-full-size-headset/anitech-headphone-with-mic-ak71-black-8859221700068_rq8jj7", "image": "https://media-cdn.bnn.in.th/84063/8859221700068-5-square_medium.jpg", "spec": {"interface": "", "type_of": "", "frequency": "", "impedance": "", "microphone": ""}}]}, {"model": "ak75", "name": "ANITECH HEADPHONE WITH MIC. AK75", "store": "Banana", "brand": "Anitech", "category": "Headset", "tag": "Gaming", "data": [{"name": "ANITECH HEADPHONE WITH MIC. AK75 BLACK", "price": 379, "href": "https://www.bnn.in.th/th/p/home-entertainment/headphone/headphone-full-size-headset/anitech-headphone-with-mic-ak75-black-8859221703847_zjgnn8", "image": "https://media-cdn.bnn.in.th/84119/8859221703847-6-square_medium.jpg", "spec": {"interface": "", "type_of": "", "frequency": "", "impedance": "", "microphone": ""}}]}, {"model": "rogstrixfusion300", "name": "ASUS GAMING HEADSET ROG STRIX FUSION 300", "store": "Banana", "brand": "Asus", "category": "Headset", "tag": "Gaming", "data": [{"name": "ASUS GAMING HEADSET ROG STRIX FUSION 300 BLACK", "price": 2490, "href": "https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-headphone/asus-gaming-headset-rog-strix-fusion-300-black-4712900693164_z974p6", "image": "https://media-cdn.bnn.in.th/117017/Asus-Gaming-Headset-ROG-Strix-Fusion-300-Black-2-square_medium.jpg", "spec": {"interface": "", "type_of": "", "frequency": "", "impedance": "", "microphone": ""}}]}, {"model": "mthp010", "name": "CS@ MEETION GAMING HEADSET MT- HP010 3.5 MM", "store": "Banana", "brand": "Meetion", "category": "Headset", "tag": "Gaming", "data": [{"name": "CS@ MEETION GAMING HEADSET MT- HP010 3.5 MM BLACK/ORANGE", "price": 370, "href": "https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-headphone/cs-at-meetion-gaming-headset-mt-hp010-35-mm-blackorange-6970344731363_dnq72d", "image": "https://media-cdn.bnn.in.th/104527/6970344731363-1-square_medium.jpg", "spec": {"interface": "", "type_of": "", "frequency": "", "impedance": "", "microphone": ""}}]}, {"model": "mthp030", "name": "CS@ MEETION GAMING HEADSET MT- HP030 USB", "store": "Banana", "brand": "Meetion", "category": "Headset", "tag": "Gaming", "data": [{"name": "CS@ MEETION GAMING HEADSET MT- HP030 USB BLACK/ORANGE", "price": 750, "href": "https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-headphone/cs-at-meetion-gaming-headset-mt-hp030-usb-blackorange-6970344731561_z957ed", "image": "https://media-cdn.bnn.in.th/104537/6970344731561-1-square_medium.jpg", "spec": {"interface": "", "type_of": "", "frequency": "", "impedance": "", "microphone": ""}}]}, {"model": "hg11", "name": "FANTECH GAMING HEADSET HG11", "store": "Banana", "brand": "Fantech", "category": "Headset", "tag": "Gaming", "data": [{"name": "FANTECH GAMING HEADSET HG11 PINK (SAKURA EDITION)", "price": 890, "href": "https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-headphone/fantech-gaming-headset-hg11-pink-sakura-edition-6972661283310_zjg09v", "image": "https://media-cdn.bnn.in.th/107368/Fantech-Gaming-Headset-HG11-PINK-(Sakura-Edition)-2-square_medium.jpg", "spec": {"interface": "", "type_of": "", "frequency": "", "impedance": "", "micr ...

# %%
with open('json_headset_gaming.json', 'w',encoding="utf-8") as f:
    f.writelines(out_headset_item)
    print("success")
# Out:
# success

# %%
export=[]

# %%
# for index,val in enumerate(advice_keyboard_working_href):
#     print("----",index,"of" ,len(advice_keyboard_working_href),"----")
#     export.append(keyboard_exit(val))

# %%
nametest = ["https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-keyboard/asus-gaming-keyboard-rog-strix-scope-pbtthblue-sw-4718017365741_dy6q2v"]
nametest
# Out:
# ['https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-keyboard/asus-gaming-keyboard-rog-strix-scope-pbtthblue-sw-4718017365741_dy6q2v']

# %%
for index,val in enumerate(nametest):
    print("----",index,"of" ,len(nametest),"----")
    export.append(keyboard_exit(val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13552/3486593738.py in <module>
# ----> 1 for index,val in enumerate(nametest):
#       2     print("----",index,"of" ,len(nametest),"----")
#       3     export.append(moused_exit(val))
#
# NameError: name 'nametest' is not defined

# %%
export
# Out:
# [None,
#  {'model': 'rogstrixscope',
#   'name': 'ASUS GAMING KEYBOARD ROG STRIX SCOPE',
#   'store': 'Banana',
#   'brand': 'Asus',
#   'category': 'Keyboard',
#   'tag': 'Gaming',
#   'data': [{'name': 'ASUS GAMING KEYBOARD ROG STRIX SCOPE PBT/TH/BLUE SW',
#     'price': 3190,
#     'href': 'https://www.bnn.in.th/th/p/gaming-gear/pc-gaming-accessories/gaming-keyboard/asus-gaming-keyboard-rog-strix-scope-pbtthblue-sw-4718017365741_dy6q2v',
#     'image': 'https://media-cdn.bnn.in.th/116583/Asus-Gaming-Keyboard-ROG-Strix-Scope-PBT-Th-Blue-SW-3-square_medium.jpg',
#     'spec': {'interface': 'USB',
#      'switch': 'N/A',
#      'layout': '',
#      'dimension': '44.0x13.7x3.9 cm',
#      'support': 'N/A'}}]}]

# %%
out_keyboard_item= json.dumps(export, ensure_ascii=False)

# %%
out_keyboard_item
# Out:
# '[{"model": "k110", "name": "HP GAMING K110", "store": "Advice", "brand": "Hp.", "category": "Keyboard", "tag": "Working", "data": [{"name": "USB KEYBOARD HP GAMING K110 BLACK", "price": 365, "href": "https://www.advice.co.th/product/keyboard/hp/usb-keyboard-hp-gaming-k110-black", "image": "https://img.advice.co.th/images_nas/pic_product4/A0131629/A0131629OK_BIG_1.jpg", "spec": {"interface": "USB", "switch": "", "layout": "104 Keys", "dimension": "(W x D x H) : 19.22 x 46.37 x 33.09 cm", "support": "Windows 7 / 8.1 / 10\\nMac OS 10.3 or later"}}]}, {"model": "k500f", "name": "HP GAMING K500F", "store": "Advice", "brand": "Hp.", "category": "Keyboard", "tag": "Working", "data": [{"name": "USB KEYBOARD HP GAMING K500F BLACK", "price": 365, "href": "https://www.advice.co.th/product/keyboard/hp/usb-keyboard-hp-gaming-k500f-black", "image": "https://img.advice.co.th/images_nas/pic_product4/A0130873/A0130873OK_BIG_1.jpg", "spec": {"interface": "USB", "switch": "", "layout": "104 Keys", "dimension": "(W x D x H) : 44.00 x 13.50 x 3.51 cm", "support": "Microsoft Windows 7 / 8 / 10"}}]}, {"model": "k120", "name": "HP GAMING K120", "store": "Advice", "brand": "Hp.", "category": "Keyboard", "tag": "Working", "data": [{"name": "USB KEYBOARD HP GAMING K120 BLACK", "price": 405, "href": "https://www.advice.co.th/product/keyboard/hp/usb-keyboard-hp-gaming-k120-black", "image": "https://img.advice.co.th/images_nas/pic_product4/A0138691/A0138691OK_BIG_1.jpg", "spec": {"interface": "USB", "switch": "", "layout": "104 Keys", "dimension": "(W x D x H) : 41.60 x 15.30 x 2.60 cm", "support": ""}}]}, {"model": "k300", "name": "HP GAMING K300", "store": "Advice", "brand": "Hp.", "category": "Keyboard", "tag": "Working", "data": [{"name": "USB KEYBOARD HP GAMING K300", "price": 415, "href": "https://www.advice.co.th/product/keyboard/hp/usb-keyboard-hp-gaming-k300", "image": "https://img.advice.co.th/images_nas/pic_product4/A0123531/A0123531OK_BIG_1.jpg", "spec": {"interface": "USB", "switch": "Non-Mechanical", "layout": "104 Keys", "dimension": "", "support": ""}}]}, {"model": "kb216", "name": "DELL KB216", "store": "Advice", "brand": "Dell", "category": "Keyboard", "tag": "Working", "data": [{"name": "USB KEYBOARD DELL (KB216) BLACK", "price": 195, "href": "https://www.advice.co.th/product/keyboard/dell/usb-keyboard-dell-kb216-black", "image": "https://img.advice.co.th/images_nas/pic_product4/A0137743/A0137743OK_BIG_1.jpg", "spec": {"interface": "USB", "switch": "", "layout": "104 Keys", "dimension": "(W x D x H) : 12.70 x 44.19 x 2.54 cm", "support": ""}}]}, {"model": "k120", "name": "HP GAMING K120", "store": "Advice", "brand": "Logitech", "category": "Keyboard", "tag": "Working", "data": [{"name": "USB KEYBOARD LOGITECH (K120) BLACK", "price": 270, "href": "https://www.advice.co.th/product/keyboard/logitech/usb-keyboard-logitech-k120-black", "image": "https://img.advice.co.th/images_nas/pic_product4/A0035187/A0035187OK_BIG_1.jpg", "spec": {"interface": "USB", "switch": "", "layout": "104 key", "dimension": "", "support": ""}}]}, null, null, {"model": "k480", "name": "BLUETOOTH KEYBOARD MULTI-DEVICE LOGITECH K480 ", "store": "Advice", "brand": "Logitech", "category": "Keyboard", "tag": "Working", "data": [{"name": "BLUETOOTH KEYBOARD MULTI-DEVICE LOGITECH K480 BLACK", "price": 1160, "href": "https://www.advice.co.th/product/keyboard/logitech/bluetooth-keyboard-multi-device-logitech-k480-black", "image": "https://img.advice.co.th/images_nas/pic_product4/A0082709/A0082709OK_BIG_1.jpg", "spec": {"interface": "BLUETOOTH", "switch": "", "layout": "82 Keys (EN\\\\TH)", "dimension": "", "support": "Windows, Mac OS, Android และ iOS"}}]}, {"model": "k480", "name": "BLUETOOTH KEYBOARD MULTI-DEVICE LOGITECH K480 ", "store": "Advice", "brand": "Logitech", "category": "Keyboard", "tag": "Working", "data": [{"name": "BLUETOOTH KEYBOARD MULTI-DEVICE LOGITECH K480 WHITE", "price": 1160, "href": "https://www.advice.co.th/product/keyboard/logitech/bluetooth-keyboard ...

# %%
with open('json_keyboard_working.json', 'w',encoding="utf-8") as f:
    f.writelines(out_keyboard_item)
    print("success")
# Out:
# success
